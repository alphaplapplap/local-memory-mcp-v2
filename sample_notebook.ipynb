# %% [markdown]
# # Local Memory MCP - Sample Notebook
#
# This notebook demonstrates how to work with your local memory MCP system.
#
# ## Features Available:
# - Memory storage and retrieval
# - PostgreSQL integration
# - Embedding generation
# - Memory consolidation

# %%
# Import your local memory MCP modules
import sys
import os
sys.path.append('src')

# Test basic imports
try:
    from src.models.memory import Memory
    from src.postgres_memory_api import PostgresMemoryAPI
    print("✅ Successfully imported memory modules")
except ImportError as e:
    print(f"❌ Import error: {e}")

# Check if we can access the database
try:
    # This will test your database connection
    print("🔍 Testing database connection...")
    # Add your connection test here
except Exception as e:
    print(f"❌ Database connection error: {e}")

# %%
# Example: Store a memory
def store_memory_example():
    """Example of storing a memory using your MCP system"""
    try:
        # Initialize your memory API
        # memory_api = PostgresMemoryAPI()
        
        # Store a sample memory
        sample_memory = {
            "content": "This is a test memory stored from Jupyter notebook",
            "metadata": {
                "source": "jupyter_notebook",
                "timestamp": "2025-01-23",
                "type": "test"
            }
        }
        
        print("📝 Sample memory to store:")
        print(sample_memory)
        
        # Uncomment when your API is ready:
        # memory_id = memory_api.store_memory(sample_memory)
        # print(f"✅ Memory stored with ID: {memory_id}")
        
    except Exception as e:
        print(f"❌ Error storing memory: {e}")

# Run the example
store_memory_example()
